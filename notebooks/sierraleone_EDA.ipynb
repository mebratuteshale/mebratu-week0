# %% [markdown]
# #### Step 0: Imports and Reading data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt 
import seaborn as sns
plt.style.use('ggplot')

# %%
# read data
df_sierraleone=pd.read_csv('../dataset/sierraleone-bumbuna.csv')

# %% [markdown]
# #### Step 1: Data Understanding
#     Dataframe shape, head and tail, dtypes, describe

# %%
# check the number of rows and columns on each data soruce
df_sierraleone.shape
# Out:
# (525600, 19)

# %%
# show some 100 rows of data from the dataframe
df_sierraleone.head(10)
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 5  2021-10-30 00:06 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 6  2021-10-30 00:07 -0.7  0.0 -0.8   0.0   0.0  22.0  99.4  0.1     0.7
# 7  2021-10-30 00:08 -0.7  0.0 -0.8   0.0   0.0  22.0  99.5  0.2     0.7
# 8  2021-10-30 00:09 -0.7 -0.1 -0.8   0.0   0.0  22.0  99.5  0.7     1.1
# 9  2021-10-30 00:10 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.6     1.1
#
#    WSstdev     WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0    0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0    0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0    0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0    0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0    0.0      0.0  1002         0            0.0   22.3   22.6
# 5      0.0    0.0      0.0  1002         0            0.0   22.3   22.7
# 6      0.2  240.4      0.0  1002         0            0.0   22.3   22.7
# 7      0.4  233.5      1.6  1002         0            0.0   22.4   22.7
# 8      0.5  232.0      0.3  1002         0            0.0   22.4   22.7
# 9      0.5  232.5      0.3  1002         0            0.0   22.4   22.7
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN

# %%
# show column from the benin dataframe
df_sierraleone.columns
# Out:
# Index(['Timestamp', 'GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS',
#        'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation',
#        'TModA', 'TModB', 'Comments'],
#       dtype='object')

# %%
# explore the data type of every column in the dataset
df_sierraleone.dtypes
# Out:
# Timestamp         object
# GHI              float64
# DNI              float64
# DHI              float64
# ModA             float64
# ModB             float64
# Tamb             float64
# RH               float64
# WS               float64
# WSgust           float64
# WSstdev          float64
# WD               float64
# WDstdev          float64
# BP                 int64
# Cleaning           int64
# Precipitation    float64
# TModA            float64
# TModB            float64
# Comments         float64
# dtype: object

# %%
# Calculate the mean, median, standard deviation, and other statistical measures for each numeric column
(df_sierraleone.drop(['Comments'],axis=1)).describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       345.400000      29.400000      96.700000       2.000000
# max      1473.000000      39.900000     100.000000      19.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.691606       0.363823     133.044668       7.172220
# std         1.617053       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max        23.900000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB
# count  525600.000000
# mean       32.593091
# std        12.009161
# min        11.100000
# 25%        23.800000
# 50%        26.900000
# 75%        41.300000
# max        70.400000

# %% [markdown]
# #### Step 2: Data Preparation
#     . Dropping irrelevant columns and rows
#     . Identifying duplicated columns
#     . Renaming columns
#     . Feature Creation
#     . change datatype of a column

# %%
# remove columns
df_sierraleone=df_sierraleone.drop(['Comments'],axis=1)

# %%
# let's change the datatype of the Timestamp column from Object type to datetime 
df_sierraleone['Timestamp']=pd.to_datetime(df_sierraleone['Timestamp'])
df_sierraleone.dtypes
# Out:
# Timestamp        datetime64[ns]
# GHI                     float64
# DNI                     float64
# DHI                     float64
# ModA                    float64
# ModB                    float64
# Tamb                    float64
# RH                      float64
# WS                      float64
# WSgust                  float64
# WSstdev                 float64
# WD                      float64
# WDstdev                 float64
# BP                        int64
# Cleaning                  int64
# Precipitation           float64
# TModA                   float64
# TModB                   float64
# dtype: object

# %%
# verify that there are no null values for each columns in the dataset
df_sierraleone.isna().sum()
# Out:
# Timestamp        0
# GHI              0
# DNI              0
# DHI              0
# ModA             0
# ModB             0
# Tamb             0
# RH               0
# WS               0
# WSgust           0
# WSstdev          0
# WD               0
# WDstdev          0
# BP               0
# Cleaning         0
# Precipitation    0
# TModA            0
# TModB            0
# dtype: int64

# %%
# check if duplicate rows exist in the dataset
df_sierraleone.loc[df_sierraleone.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, GHI, DNI, DHI, ModA, ModB, Tamb, RH, WS, WSgust, WSstdev, WD, WDstdev, BP, Cleaning, Precipitation, TModA, TModB]
# Index: []

# %%
# remove rows with negative value of GHI, DNI, and DHI columns as these columns are expected tobe greater than 0
# 243k rows will be returned
df_sierraleone=df_sierraleone[(df_sierraleone['DHI']>0) & (df_sierraleone['DNI']>0) & (df_sierraleone['DHI']>0)]

# %% [markdown]
# ##### Checking Outliers
#     . TModA and TModB

# %%
# combine TModA and TModB save the average temprateur as TempAvg
# values less than 14 of the TempAvg column are considered as Outliers 

df_sierraleone['TempAvg'] = (df_sierraleone['TModA'] + df_sierraleone['TModB']) / 2

sns.boxplot(df_sierraleone['TempAvg'])
plt.title('Original Box Plot of Avg Temp')
plt.show()

threshold = 14
df_sierraleone = df_sierraleone[df_sierraleone['TempAvg'] >= threshold]

sns.boxplot(df_sierraleone['TempAvg'])
plt.title(f'Box Plot without Outliers of Avg Temp')
plt.show()

df_sierraleone.shape
# Out:
# (230506, 19)

# %%
# check outliers in the WS and WSgust columns
sns.boxplot(df_sierraleone['WS'])
# Out:
# <Axes: ylabel='WS'>

# %% [markdown]
# ##### Impact of Cleaning against Temprature reading
#     (A boxplot is used to visualize the impact of cleaning)

# %%
# Show the impact of cleaning in the temprature 
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.boxplot(x='Cleaning', y='TempAvg', data=df_sierraleone, hue='Cleaning', palette="Set2")

# Customize the plot
plt.title('Impact of Cleaning on Temperature Readings', fontsize=14)
plt.xlabel('Clean (0 = Not Cleaned, 1 = Cleaned)', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.show()

# %% [markdown]
# ##### Time Series Analysis
#      (Bar charts and Line charts are used over time to observe patterns by month of GHI, DNI, DHI, and Tamb data)

# %%
# Convert 'Timestamp' to datetime and create a 'Month' column
df_sierraleone['Timestamp'] = pd.to_datetime(df_sierraleone['Timestamp'])
df_sierraleone['Month'] = df_sierraleone['Timestamp'].dt.strftime('%Y-%m')  # Format as 'YYYY-MM'

# Aggregate data by month
monthly_avg = df_sierraleone.groupby('Month')[['GHI', 'DNI', 'DHI', 'TempAvg']].mean()

# Plotting line chart for monthly trends
plt.figure(figsize=(12, 6))
for column in ['GHI', 'DNI', 'DHI', 'TempAvg']:
    plt.plot(monthly_avg.index, monthly_avg[column], label=column, marker='o')

# Customize the plot
plt.title('Monthly Trends of GHI, DNI, DHI, and TempAvg', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Values', fontsize=12)
plt.legend(title='Metrics')
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plotting bar chart for monthly trends
monthly_avg.plot(kind='bar', figsize=(12, 6), alpha=0.8)
plt.title('Monthly Trends of GHI, DNI, DHI, and TempAvg (Bar Chart)', fontsize=16)
plt.ylabel('Average Values', fontsize=12)
plt.xlabel('Month', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Metrics')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Correlation Analysis

# %%
# Correlation Analysis: Using correlation matrices and pair plots to visualize the correlations between solar radiation components (GHI, DNI, DHI) and temperature measures
correlation_matrix = df_sierraleone[['GHI', 'DNI', 'DHI', 'TempAvg']].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)
plt.title('Correlation Matrix of Solar Radiation Components and Temperature', fontsize=14)
plt.show()

# Create a pair plot to visualize pairwise relationships
sns.pairplot(df_sierraleone[['GHI', 'DNI', 'DHI', 'TempAvg']], diag_kind='kde', corner=True, plot_kws={'alpha': 0.7})
plt.suptitle('Pair Plot of Solar Radiation Components and Temperature', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ##### Wind Analysis:
#     . using Radial bar plots or Wind roses identify trends and significant wind events by showing the distribution of wind speed and direction, along with how variable the wind direction tends to be.

# %%
from matplotlib.cm import get_cmap

df_sierraleone['WD_bin'] = pd.cut(df_sierraleone['WD'], bins=np.arange(0, 361, 30), labels=np.arange(15, 361, 30))

# Compute mean wind speed and standard deviation for each wind direction bin
wind_stats = df_sierraleone.groupby('WD_bin').agg({
    'WS': ['mean', 'max'],
    'WDstdev': 'mean',
}, observed=True).reset_index()
wind_stats.columns = ['Wind_Direction', 'WS_mean', 'WS_max', 'WDstdev_mean']

# Convert wind direction bins to radians for plotting
angles = np.deg2rad(np.arange(15, 361, 30))

# Radial bar plot (Wind Rose)
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Plot mean wind speed as bars
bars = ax.bar(angles, wind_stats['WS_mean'], width=np.deg2rad(30), 
              color=get_cmap('viridis')(wind_stats['WS_mean'] / wind_stats['WS_mean'].max()), 
              edgecolor='black', alpha=0.7, label='Mean WS')

# Plot max wind speed as markers
ax.scatter(angles, wind_stats['WS_max'], color='red', label='Max WS', zorder=5)

# Customize the plot
ax.set_theta_offset(np.pi / 2)  # Set 0 degrees (North) to the top
ax.set_theta_direction(-1)     # Clockwise direction
ax.set_xticks(angles)
ax.set_xticklabels([f"{int(d)}°" for d in np.arange(15, 361, 30)])
ax.set_yticks(range(0, int(wind_stats['WS_max'].max()) + 2, 2))
ax.set_yticklabels(range(0, int(wind_stats['WS_max'].max()) + 2, 2))
ax.set_title("Wind Rose: Distribution of Wind Speed and Direction", fontsize=16, pad=20)
ax.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\mteshale\AppData\Local\Temp\ipykernel_8908\817668994.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wind_stats = df_sierraleone.groupby('WD_bin').agg({
# C:\Users\mteshale\AppData\Local\Temp\ipykernel_8908\817668994.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color=get_cmap('viridis')(wind_stats['WS_mean'] / wind_stats['WS_mean'].max()),

# %% [markdown]
# ##### Temperature Analysis:
#     . Examine how relative humidity (RH) might influence temperature readings and solar radiation.

# %%
# Scatter plots with regression lines
plt.figure(figsize=(14, 12))

# RH vs Tamb
plt.subplot(2, 2, 1)
sns.regplot(x='RH', y='Tamb', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Temperature (Tamb)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Temperature (°C)')

# RH vs GHI
plt.subplot(2, 2, 2)
sns.regplot(x='RH', y='GHI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Global Horizontal Irradiance (GHI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('GHI (W/m²)')

# RH vs DNI
plt.subplot(2, 2, 3)
sns.regplot(x='RH', y='DNI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Direct Normal Irradiance (DNI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DNI (W/m²)')

# RH vs DHI
plt.subplot(2, 2, 4)
sns.regplot(x='RH', y='DHI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Diffuse Horizontal Irradiance (DHI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DHI (W/m²)')

plt.tight_layout()
plt.show()

# %%
# Correlation matrix
correlation_matrix = df_sierraleone[['RH', 'Tamb', 'GHI', 'DNI', 'DHI']].corr()
print("Correlation Matrix:\n", correlation_matrix)

# Heatmap to visualize correlations
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f',
    cbar_kws={"shrink": 0.8}, linewidths=0.5
)
plt.title('Correlation Matrix: RH, Temperature, and Solar Radiation', fontsize=14)
plt.show()

# Scatter plots with regression lines
plt.figure(figsize=(14, 10))

# RH vs Tamb
plt.subplot(2, 2, 1)
sns.regplot(x='RH', y='Tamb', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Temperature (Tamb)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Temperature (°C)')

# RH vs GHI
plt.subplot(2, 2, 2)
sns.regplot(x='RH', y='GHI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Global Horizontal Irradiance (GHI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('GHI (W/m²)')

# RH vs DNI
plt.subplot(2, 2, 3)
sns.regplot(x='RH', y='DNI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Direct Normal Irradiance (DNI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DNI (W/m²)')

# RH vs DHI
plt.subplot(2, 2, 4)
sns.regplot(x='RH', y='DHI', data=df_sierraleone, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('RH vs Diffuse Horizontal Irradiance (DHI)')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DHI (W/m²)')

plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#              RH      Tamb       GHI       DNI       DHI
# RH    1.000000 -0.841579 -0.367278 -0.436665 -0.078786
# Tamb -0.841579  1.000000  0.439242  0.431406  0.201438
# GHI  -0.367278  0.439242  1.000000  0.797395  0.650609
# DNI  -0.436665  0.431406  0.797395  1.000000  0.107598
# DHI  -0.078786  0.201438  0.650609  0.107598  1.000000

# %% [markdown]
# ##### Histograms:
#     Create histograms for variables like GHI, DNI, DHI, WS, and temperatures to visualize the frequency distribution of these variables.

# %%
# Plot histograms for each variable
variables = ['GHI', 'DNI', 'DHI', 'WS', 'Tamb']
plt.figure(figsize=(12, 10))

for i, var in enumerate(variables, 1):
    plt.subplot(3, 2, i)  # Arrange subplots in a grid
    sns.histplot(df_sierraleone[var], kde=True, bins=15, color='skyblue', alpha=0.7)
    plt.title(f'Histogram of {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Calculate Z-scores to flag data points that are significantly different from the mean

# %%
# Calculate Z-scores for each column
from scipy.stats import zscore
selected_cols = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS','WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'TModA', 'TModB']
# Calculate mean and standard deviation for selected features
means = df_sierraleone[selected_cols].mean()
stds = df_sierraleone[selected_cols].std()

# Calculate Z-scores for selected columns
z_scores = ((df_sierraleone[selected_cols] - means) / stds)

zscore_threshold=3
# Detect outliers based on the threshold which is 3
outliers = (np.abs(z_scores) > zscore_threshold).any(axis=1)

# Filter outliers from the dataset
filtered_data = df_sierraleone[~outliers]

# Visualize the original dataset
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df_sierraleone['Tamb'], df_sierraleone['WS'], color='blue', label='Original Data')
plt.xlabel('Ambient Temprature (Tamb)')
plt.ylabel('Wind Speed (WS)')
plt.title('Original Dataset')

# Visualize the filtered dataset without outliers
plt.subplot(1, 2, 2)
plt.scatter(filtered_data['Tamb'], filtered_data['WS'], color='green', label='Filtered Data')
plt.xlabel('Ambient Temprature (Tamb)')
plt.ylabel('Wind Speed (WS)')
plt.title('Dataset without Outliers (Threshold = {})'.format(zscore_threshold))
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Bubble Chart: GHI vs. Tamb vs. WS

# %%
# Create a Bubble chart: GHI vs Tamb vs WS, with bubble size representing RH
sns.scatterplot(
    x='GHI', y='Tamb', size='BP', data=df_sierraleone, 
    sizes=(20, 1500), # Adjust the size range for bubbles
    color='gray', alpha=0.6, legend=True
)
plt.title('Bubble Chart: GHI vs Tamb (with BP as Bubble Size)', fontsize=14)
plt.xlabel('Global Horizontal Irradiance (GHI) [W/m²]')
plt.ylabel('Temperature (Tamb) [°C]')
plt.tight_layout()
plt.show()
